# %%
import sys
sys.path.append("../src")

# %%
from screening_engine import ScreeningEngine

engine = ScreeningEngine("../data/master_screening_dataset.csv")

# %%
engine.screen("Mohammed Ali")
# Out:
# {'status': 'No Match', 'details': None}

# %%
engine.screen("Mohammed Ali", country="Pakistan")
# Out:
# {'status': 'Potential Match',
#  'count': 1,
#  'matches': [{'input_name': 'Mohammed Ali',
#    'match_name': 'Ali Mohammed Kareem',
#    'list_type': 'OFAC_SDN',
#    'country': 'Iraq',
#    'address': nan,
#    'name_score': 100,
#    'country_score': 50,
#    'address_score': 0,
#    'final_score': 80.0}]}

# %%
engine.screen("Ali Hassan", address="Tehran")
# Out:
# {'status': 'No Match', 'details': None}
